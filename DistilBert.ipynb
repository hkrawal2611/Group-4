# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from transformers import AutoTokenizer, AutoModel, AdamW
from torch.utils.data import DataLoader, Dataset
import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn.metrics import classification_report

# Load the dataset
data = pd.read_csv('/kaggle/input/new-dataset/nlp_dataset.csv')

# Data Preparation: Select relevant columns
data = data[['hypothesis', 'premise', 'label']].dropna()
data['label'] = data['label'].map({'n': 0, 'c': 1})  # Map 'n' to 0 and 'c' to 
data.head()
# Out:
#                                           hypothesis  \
# 0  further the paper makes several misleading cla...
# 1  4 .i like the key idea and the speedup is very...
# 2  the idea to use sampling is nice but the analy...
# 3  to summarize i think this paper give some empi...
# 4  to summarize i think this paper give some empi...
#
#                                              premise  label
# 0  the paper is rather well written but it strong...      0
# 1  review scores reflect this reviewers impressio...      0
# 2  review scores reflect this reviewers impressio...      0
# 3  in my opinion the overall quality of the paper...      0
# 4  the context and relevance as well as the contr...      0

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
# Split the data into train, validation, and test sets
train_data, temp_data = train_test_split(data, test_size=0.3, random_state=42)
val_data, test_data = train_test_split(temp_data, test_size=0.5, random_state=42)

# %%
from transformers import DistilBertTokenizer, DistilBertModel

# Dataset Class for DataLoader
class ReviewPairDataset(Dataset):
    def __init__(self, dataframe, tokenizer, max_len=128):
        self.data = dataframe
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        row = self.data.iloc[index]
        inputs = self.tokenizer(
            row['hypothesis'],
            row['premise'],
            add_special_tokens=True,
            max_length=self.max_len,
            truncation=True,
            padding='max_length',
            return_tensors="pt"
        )
        return {
            'input_ids': inputs['input_ids'].squeeze(0),
            'attention_mask': inputs['attention_mask'].squeeze(0),
            'label': torch.tensor(row['label'], dtype=torch.long)
        }

# Load pre-trained tokenizer
tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-cased")

# %%
# Create DataLoaders
train_dataset = ReviewPairDataset(train_data, tokenizer)
val_dataset = ReviewPairDataset(val_data, tokenizer)
test_dataset = ReviewPairDataset(test_data, tokenizer)

# %%
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32)
test_loader = DataLoader(test_dataset, batch_size=32)

# %%
class ContrastiveClassifier(nn.Module):
    def __init__(self, model_name, embedding_dim=768):
        super(ContrastiveClassifier, self).__init__()
        self.encoder = DistilBertModel.from_pretrained(model_name)
        self.fc = nn.Linear(embedding_dim, 2)  # Binary classification

    def forward(self, input_ids, attention_mask):
        # Get the hidden state of the [CLS] token
        outputs = self.encoder(input_ids, attention_mask)
        cls_embeddings = outputs.last_hidden_state[:, 0, :]  # CLS token embeddings
        outputs = self.fc(cls_embeddings)
        return outputs

model_name = "distilbert-base-uncased"
model = ContrastiveClassifier(model_name)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# ContrastiveClassifier(
#   (encoder): DistilBertModel(
#     (embeddings): Embeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): Transformer(
#       (layer): ModuleList(
#         (0-5): 6 x TransformerBlock(
#           (attention): DistilBertSdpaAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (fc): Linear(in_features=768, out_features=2, bias=True)
# )

# %%
# Define Optimizer and Loss Function
optimizer = AdamW(model.parameters(), lr=2e-5)
criterion = nn.CrossEntropyLoss()
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
from tqdm import tqdm
import time

# Training Function with TQDM and Timing
def train_model(model, train_loader, val_loader, optimizer, criterion, device, epochs=3):
    for epoch in range(epochs):
        start_time = time.time()  # Start timing the epoch
        
        # Training phase
        model.train()
        train_loss = 0
        train_loader_tqdm = tqdm(train_loader, desc=f"Epoch {epoch + 1} Training", leave=False)
        
        for batch in train_loader_tqdm:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['label'].to(device)

            optimizer.zero_grad()
            outputs = model(input_ids, attention_mask)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

            # Update TQDM description with current batch loss
            train_loader_tqdm.set_postfix(loss=loss.item())

        avg_train_loss = train_loss / len(train_loader)
        print(f"Epoch {epoch + 1}, Train Loss: {avg_train_loss:.4f}")

        # Validation phase
        model.eval()
        val_loss = 0
        val_preds, val_labels = [], []
        val_loader_tqdm = tqdm(val_loader, desc=f"Epoch {epoch + 1} Validation", leave=False)
        
        with torch.no_grad():
            for batch in val_loader_tqdm:
                input_ids = batch['input_ids'].to(device)
                attention_mask = batch['attention_mask'].to(device)
                labels = batch['label'].to(device)

                outputs = model(input_ids, attention_mask)
                loss = criterion(outputs, labels)
                val_loss += loss.item()

                preds = torch.argmax(outputs, dim=1)
                val_preds.extend(preds.cpu().numpy())
                val_labels.extend(labels.cpu().numpy())

                # Update TQDM description with current batch loss
                val_loader_tqdm.set_postfix(loss=loss.item())

        avg_val_loss = val_loss / len(val_loader)
        print(f"Validation Loss: {avg_val_loss:.4f}")
        print(classification_report(val_labels, val_preds))

        # Calculate and print epoch time
        end_time = time.time()
        epoch_time = end_time - start_time
        print(f"Epoch {epoch + 1} completed in {epoch_time:.2f} seconds")

# Train the Model
train_model(model, train_loader, val_loader, optimizer, criterion, device, epochs=3)
# Out:
# Epoch 1 Training:   0%|          | 0/1050 [00:00<?, ?it/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:   0%|          | 3/1050 [00:01<06:54,  2.53it/s, loss=0.469]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:   1%|          | 8/1050 [00:03<06:48,  2.55it/s, loss=0.315]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:   1%|          | 11/1050 [00:04<06:49,  2.54it/s, loss=0.526]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:   1%|▏         | 15/1050 [00:05<06:48,  2.53it/s, loss=0.23] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:   2%|▏         | 18/1050 [00:07<06:55,  2.48it/s, loss=0.247]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:   2%|▏         | 20/1050 [00:07<06:56,  2.47it/s, loss=0.357]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:   2%|▏         | 22/1050 [00:08<06:59,  2.45it/s, loss=0.327]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:   2%|▏         | 26/1050 [00:10<06:56,  2.46it/s, loss=0.522]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:   3%|▎         | 28/1050 [00:11<07:00,  2.43it/s, loss=0.334]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:   3%|▎         | 30/1050 [00:12<07:03,  2.41it/s, loss=0.42] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:   3%|▎         | 33/1050 [00:13<07:04,  2.39it/s, loss=0.269]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:   4%|▎         | 38/1050 [00:15<07:02,  2.39it/s, loss=0.312]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:   4%|▎         | 39/1050 [00:15<07:01,  2.40it/s, loss=0.189]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:   4%|▍         | 42/1050 [00:17<06:58,  2.41it/s, loss=0.481]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:   5%|▌         | 55/1050 [00:22<06:36,  2.51it/s, loss=0.278]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:   6%|▌         | 63/1050 [00:25<06:26,  2.55it/s, loss=0.431] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:   7%|▋         | 69/1050 [00:27<06:18,  2.59it/s, loss=0.386]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:   7%|▋         | 71/1050 [00:28<06:17,  2.59it/s, loss=0.6]  Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:   7%|▋         | 73/1050 [00:29<06:17,  2.59it/s, loss=0.364]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:   7%|▋         | 77/1050 [00:30<06:12,  2.61it/s, loss=0.436]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:   8%|▊         | 81/1050 [00:32<06:08,  2.63it/s, loss=0.406]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:   8%|▊         | 85/1050 [00:33<06:03,  2.66it/s, loss=0.33] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:   8%|▊         | 88/1050 [00:35<06:01,  2.66it/s, loss=0.403]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:   9%|▊         | 90/1050 [00:35<06:02,  2.65it/s, loss=0.223]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:   9%|▊         | 91/1050 [00:36<06:01,  2.65it/s, loss=0.238]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:   9%|▉         | 94/1050 [00:37<05:57,  2.67it/s, loss=0.555]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:   9%|▉         | 95/1050 [00:37<05:57,  2.67it/s, loss=0.353]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:   9%|▉         | 96/1050 [00:38<05:57,  2.67it/s, loss=0.301]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  10%|█         | 106/1050 [00:41<05:47,  2.72it/s, loss=0.38] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  10%|█         | 107/1050 [00:42<05:47,  2.72it/s, loss=0.234]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  11%|█         | 113/1050 [00:44<05:43,  2.73it/s, loss=0.21] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  11%|█         | 114/1050 [00:44<05:44,  2.72it/s, loss=0.382]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  11%|█▏        | 119/1050 [00:46<05:41,  2.73it/s, loss=0.255]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  12%|█▏        | 121/1050 [00:47<05:40,  2.73it/s, loss=0.275]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  12%|█▏        | 124/1050 [00:48<05:39,  2.72it/s, loss=0.283]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  12%|█▏        | 130/1050 [00:50<05:35,  2.75it/s, loss=0.323]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  12%|█▏        | 131/1050 [00:50<05:34,  2.74it/s, loss=0.346]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  13%|█▎        | 134/1050 [00:51<05:33,  2.75it/s, loss=0.307]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  13%|█▎        | 135/1050 [00:52<05:34,  2.74it/s, loss=0.385]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  14%|█▎        | 144/1050 [00:55<05:28,  2.76it/s, loss=0.326]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  14%|█▍        | 145/1050 [00:55<05:29,  2.74it/s, loss=0.275]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  14%|█▍        | 148/1050 [00:57<05:27,  2.75it/s, loss=0.471]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  14%|█▍        | 150/1050 [00:57<05:28,  2.74it/s, loss=0.419]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  16%|█▌        | 163/1050 [01:02<05:28,  2.70it/s, loss=0.421]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  16%|█▌        | 170/1050 [01:05<05:21,  2.74it/s, loss=0.594]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  16%|█▋        | 172/1050 [01:05<05:22,  2.72it/s, loss=0.382]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  17%|█▋        | 174/1050 [01:06<05:20,  2.73it/s, loss=0.242]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  17%|█▋        | 179/1050 [01:08<05:18,  2.74it/s, loss=0.381]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  17%|█▋        | 182/1050 [01:09<05:19,  2.72it/s, loss=0.314]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  18%|█▊        | 184/1050 [01:10<05:18,  2.72it/s, loss=0.305]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  18%|█▊        | 186/1050 [01:10<05:19,  2.70it/s, loss=0.326]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  18%|█▊        | 190/1050 [01:12<05:15,  2.72it/s, loss=0.331]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  18%|█▊        | 191/1050 [01:12<05:17,  2.71it/s, loss=0.327]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  18%|█▊        | 193/1050 [01:13<05:16,  2.71it/s, loss=0.289]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  19%|█▊        | 195/1050 [01:14<05:17,  2.69it/s, loss=0.222]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  20%|█▉        | 207/1050 [01:18<05:16,  2.66it/s, loss=0.627]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  20%|█▉        | 209/1050 [01:19<05:16,  2.66it/s, loss=0.483]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  21%|██        | 219/1050 [01:23<05:15,  2.64it/s, loss=0.364]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  21%|██        | 222/1050 [01:24<05:16,  2.62it/s, loss=0.301]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  21%|██        | 223/1050 [01:24<05:16,  2.61it/s, loss=0.473]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  21%|██▏       | 224/1050 [01:25<05:16,  2.61it/s, loss=0.328]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  22%|██▏       | 228/1050 [01:26<05:15,  2.60it/s, loss=0.371]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  22%|██▏       | 232/1050 [01:28<05:16,  2.58it/s, loss=0.376]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  22%|██▏       | 236/1050 [01:29<05:14,  2.58it/s, loss=0.459]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  23%|██▎       | 238/1050 [01:30<05:14,  2.58it/s, loss=0.502]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  23%|██▎       | 240/1050 [01:31<05:13,  2.59it/s, loss=0.368]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  24%|██▎       | 247/1050 [01:34<05:08,  2.60it/s, loss=0.382]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  24%|██▎       | 249/1050 [01:34<05:08,  2.59it/s, loss=0.427]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  24%|██▍       | 251/1050 [01:35<05:09,  2.58it/s, loss=0.181]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  24%|██▍       | 252/1050 [01:36<05:09,  2.58it/s, loss=0.178]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  24%|██▍       | 253/1050 [01:36<05:09,  2.57it/s, loss=0.369]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  24%|██▍       | 255/1050 [01:37<05:07,  2.59it/s, loss=0.384]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  25%|██▍       | 262/1050 [01:39<05:00,  2.62it/s, loss=0.763] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  26%|██▌       | 268/1050 [01:42<04:57,  2.63it/s, loss=0.224]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  26%|██▌       | 272/1050 [01:43<04:54,  2.64it/s, loss=0.314]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  26%|██▌       | 273/1050 [01:44<04:54,  2.64it/s, loss=0.375]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  26%|██▋       | 276/1050 [01:45<04:53,  2.64it/s, loss=0.395]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  27%|██▋       | 285/1050 [01:48<04:50,  2.63it/s, loss=0.236]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  28%|██▊       | 289/1050 [01:50<04:49,  2.63it/s, loss=0.24] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  28%|██▊       | 294/1050 [01:52<04:46,  2.64it/s, loss=0.235]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  29%|██▊       | 300/1050 [01:54<04:42,  2.65it/s, loss=0.326]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  29%|██▉       | 306/1050 [01:56<04:39,  2.66it/s, loss=0.295]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  30%|██▉       | 312/1050 [01:58<04:37,  2.66it/s, loss=0.28] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  30%|███       | 318/1050 [02:01<04:34,  2.66it/s, loss=0.346]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  31%|███       | 326/1050 [02:04<04:30,  2.68it/s, loss=0.299]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  31%|███       | 327/1050 [02:04<04:31,  2.67it/s, loss=0.166]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  31%|███       | 328/1050 [02:04<04:31,  2.66it/s, loss=0.25] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  31%|███▏      | 329/1050 [02:05<04:32,  2.65it/s, loss=0.289]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  32%|███▏      | 332/1050 [02:06<04:29,  2.66it/s, loss=0.257]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  32%|███▏      | 334/1050 [02:07<04:27,  2.68it/s, loss=0.248]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  32%|███▏      | 335/1050 [02:07<04:28,  2.67it/s, loss=0.319]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  33%|███▎      | 342/1050 [02:10<04:22,  2.69it/s, loss=0.22] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  33%|███▎      | 346/1050 [02:11<04:20,  2.71it/s, loss=0.344]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  33%|███▎      | 349/1050 [02:12<04:21,  2.68it/s, loss=0.397]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  33%|███▎      | 350/1050 [02:13<04:22,  2.66it/s, loss=0.302]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  34%|███▍      | 362/1050 [02:17<04:14,  2.70it/s, loss=0.433]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  35%|███▍      | 363/1050 [02:17<04:15,  2.69it/s, loss=0.491]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  35%|███▍      | 366/1050 [02:19<04:14,  2.69it/s, loss=0.373]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  35%|███▍      | 367/1050 [02:19<04:13,  2.69it/s, loss=0.235]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  35%|███▌      | 368/1050 [02:19<04:13,  2.69it/s, loss=0.515]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  36%|███▌      | 377/1050 [02:23<04:11,  2.67it/s, loss=0.288]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  36%|███▌      | 380/1050 [02:24<04:11,  2.66it/s, loss=0.574]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  37%|███▋      | 384/1050 [02:25<04:08,  2.68it/s, loss=0.355]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  37%|███▋      | 390/1050 [02:28<04:05,  2.69it/s, loss=0.405]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  37%|███▋      | 393/1050 [02:29<04:05,  2.67it/s, loss=0.313]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  39%|███▊      | 406/1050 [02:33<04:00,  2.68it/s, loss=0.558]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  39%|███▉      | 407/1050 [02:34<04:00,  2.68it/s, loss=0.416]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  39%|███▉      | 408/1050 [02:34<04:01,  2.65it/s, loss=0.358]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  39%|███▉      | 410/1050 [02:35<03:59,  2.67it/s, loss=0.438]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  41%|████▏     | 434/1050 [02:44<03:49,  2.68it/s, loss=0.386]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  42%|████▏     | 446/1050 [02:48<03:46,  2.67it/s, loss=0.282]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  43%|████▎     | 450/1050 [02:50<03:46,  2.65it/s, loss=0.387]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  43%|████▎     | 456/1050 [02:52<03:44,  2.64it/s, loss=0.24] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  44%|████▎     | 459/1050 [02:53<03:44,  2.64it/s, loss=0.499]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  44%|████▍     | 463/1050 [02:55<03:41,  2.65it/s, loss=0.453]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  44%|████▍     | 465/1050 [02:56<03:41,  2.64it/s, loss=0.307]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  45%|████▍     | 470/1050 [02:58<03:38,  2.65it/s, loss=0.281]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  45%|████▌     | 474/1050 [02:59<03:38,  2.63it/s, loss=0.254]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  45%|████▌     | 475/1050 [02:59<03:38,  2.63it/s, loss=0.415]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  45%|████▌     | 477/1050 [03:00<03:37,  2.63it/s, loss=0.285]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  46%|████▌     | 483/1050 [03:02<03:33,  2.66it/s, loss=0.268]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  46%|████▌     | 484/1050 [03:03<03:35,  2.63it/s, loss=0.354]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  47%|████▋     | 490/1050 [03:05<03:32,  2.64it/s, loss=0.234]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  48%|████▊     | 501/1050 [03:09<03:26,  2.65it/s, loss=0.34] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  48%|████▊     | 502/1050 [03:10<03:27,  2.64it/s, loss=0.169]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  48%|████▊     | 503/1050 [03:10<03:28,  2.62it/s, loss=0.538]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  48%|████▊     | 508/1050 [03:12<03:26,  2.62it/s, loss=0.278]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  49%|████▉     | 516/1050 [03:15<03:21,  2.65it/s, loss=0.167]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  49%|████▉     | 517/1050 [03:15<03:21,  2.64it/s, loss=0.284]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  49%|████▉     | 518/1050 [03:16<03:21,  2.63it/s, loss=0.262]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  49%|████▉     | 519/1050 [03:16<03:21,  2.63it/s, loss=0.487]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  50%|████▉     | 523/1050 [03:18<03:19,  2.64it/s, loss=0.365]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  50%|█████     | 529/1050 [03:20<03:17,  2.64it/s, loss=0.305]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  51%|█████     | 534/1050 [03:22<03:13,  2.67it/s, loss=0.339]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  51%|█████     | 538/1050 [03:23<03:12,  2.66it/s, loss=0.448]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  51%|█████▏    | 539/1050 [03:24<03:14,  2.63it/s, loss=0.245]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  52%|█████▏    | 543/1050 [03:25<03:11,  2.64it/s, loss=0.574]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  52%|█████▏    | 548/1050 [03:27<03:09,  2.66it/s, loss=0.406]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  52%|█████▏    | 551/1050 [03:28<03:07,  2.66it/s, loss=0.289]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 1 Training:  53%|█████▎    | 558/1050 [03:31<03:05,  2.65it/s, loss=0.299]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# ...
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  31%|███       | 69/225 [00:09<00:21,  7.27it/s, loss=0.484]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  32%|███▏      | 72/225 [00:09<00:20,  7.30it/s, loss=0.34] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  34%|███▍      | 76/225 [00:10<00:20,  7.33it/s, loss=0.239] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  34%|███▍      | 77/225 [00:10<00:20,  7.28it/s, loss=0.111]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  35%|███▌      | 79/225 [00:10<00:20,  7.26it/s, loss=0.16] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  36%|███▌      | 81/225 [00:11<00:19,  7.21it/s, loss=0.315]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  38%|███▊      | 86/225 [00:11<00:18,  7.38it/s, loss=0.227]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  39%|███▉      | 88/225 [00:12<00:18,  7.33it/s, loss=0.249]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  42%|████▏     | 94/225 [00:12<00:17,  7.35it/s, loss=0.304] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  42%|████▏     | 95/225 [00:13<00:17,  7.35it/s, loss=0.386]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  45%|████▍     | 101/225 [00:13<00:16,  7.33it/s, loss=0.16] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  49%|████▉     | 110/225 [00:15<00:15,  7.29it/s, loss=0.142]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  49%|████▉     | 111/225 [00:15<00:15,  7.23it/s, loss=0.475]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  50%|█████     | 113/225 [00:15<00:15,  7.21it/s, loss=0.19] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  52%|█████▏    | 117/225 [00:16<00:14,  7.24it/s, loss=0.492]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  52%|█████▏    | 118/225 [00:16<00:14,  7.22it/s, loss=0.367]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  54%|█████▍    | 122/225 [00:16<00:14,  7.20it/s, loss=0.193]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  56%|█████▋    | 127/225 [00:17<00:13,  7.34it/s, loss=0.349]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  57%|█████▋    | 128/225 [00:17<00:13,  7.29it/s, loss=0.321]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  57%|█████▋    | 129/225 [00:17<00:13,  7.24it/s, loss=0.254]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  60%|█████▉    | 134/225 [00:18<00:12,  7.32it/s, loss=0.154]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  61%|██████▏   | 138/225 [00:18<00:11,  7.39it/s, loss=0.692]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  64%|██████▎   | 143/225 [00:19<00:11,  7.36it/s, loss=0.498]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  69%|██████▉   | 155/225 [00:21<00:09,  7.30it/s, loss=0.229] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  72%|███████▏  | 161/225 [00:22<00:08,  7.30it/s, loss=0.485]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  75%|███████▌  | 169/225 [00:23<00:07,  7.33it/s, loss=0.455]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  82%|████████▏ | 184/225 [00:25<00:05,  7.34it/s, loss=0.223]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  82%|████████▏ | 185/225 [00:25<00:05,  7.29it/s, loss=0.319]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  83%|████████▎ | 186/225 [00:25<00:05,  7.23it/s, loss=0.175]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  85%|████████▍ | 191/225 [00:26<00:04,  7.29it/s, loss=0.23] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  86%|████████▌ | 194/225 [00:26<00:04,  7.34it/s, loss=0.184]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  87%|████████▋ | 195/225 [00:26<00:04,  7.26it/s, loss=0.382]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  87%|████████▋ | 196/225 [00:26<00:03,  7.28it/s, loss=0.237]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  88%|████████▊ | 197/225 [00:27<00:03,  7.25it/s, loss=0.304]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  88%|████████▊ | 198/225 [00:27<00:03,  7.26it/s, loss=0.329]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  88%|████████▊ | 199/225 [00:27<00:03,  7.28it/s, loss=0.25] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  90%|████████▉ | 202/225 [00:27<00:03,  7.23it/s, loss=0.243]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  91%|█████████ | 205/225 [00:28<00:02,  7.33it/s, loss=0.197]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  92%|█████████▏| 207/225 [00:28<00:02,  7.28it/s, loss=0.367]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  95%|█████████▌| 214/225 [00:29<00:01,  7.35it/s, loss=0.219]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  97%|█████████▋| 219/225 [00:30<00:00,  7.35it/s, loss=0.34] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  98%|█████████▊| 220/225 [00:30<00:00,  7.32it/s, loss=0.5] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation:  98%|█████████▊| 221/225 [00:30<00:00,  7.31it/s, loss=0.537]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Epoch 3 Validation: 100%|█████████▉| 224/225 [00:30<00:00,  7.33it/s, loss=0.181]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Validation Loss: 0.3143
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93      6346
#            1       0.50      0.26      0.34       850
#
#     accuracy                           0.88      7196
#    macro avg       0.70      0.61      0.64      7196
# weighted avg       0.86      0.88      0.86      7196
#
# Epoch 3 completed in 425.40 seconds

# %%
# Save the model
torch.save(model.state_dict(), "contrastive_classifier.pt")

# Inference on Test Data with TQDM
def evaluate_model(model, test_loader, device):
    model.eval()
    test_preds, test_labels = [], []
    test_loader_tqdm = tqdm(test_loader, desc="Evaluating on Test Data", leave=False)

    with torch.no_grad():
        for batch in test_loader_tqdm:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['label'].to(device)

            outputs = model(input_ids, attention_mask)
            preds = torch.argmax(outputs, dim=1)
            test_preds.extend(preds.cpu().numpy())
            test_labels.extend(labels.cpu().numpy())

            # Optionally, display intermediate batch-level accuracy in the TQDM bar
            batch_accuracy = (preds.cpu().numpy() == labels.cpu().numpy()).mean()
            test_loader_tqdm.set_postfix(batch_accuracy=batch_accuracy)

    print("Test Results:")
    print(classification_report(test_labels, test_preds))

# Evaluate on Test Data
evaluate_model(model, test_loader, device)
# Out:
# Evaluating on Test Data:   0%|          | 0/225 [00:00<?, ?it/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:   2%|▏         | 4/225 [00:00<00:32,  6.78it/s, batch_accuracy=0.812]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:   3%|▎         | 7/225 [00:01<00:31,  7.02it/s, batch_accuracy=0.719]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:   4%|▍         | 9/225 [00:01<00:30,  7.08it/s, batch_accuracy=0.688]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:   5%|▍         | 11/225 [00:01<00:31,  6.87it/s, batch_accuracy=0.875]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:   9%|▉         | 20/225 [00:02<00:29,  6.86it/s, batch_accuracy=0.844]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  11%|█         | 24/225 [00:03<00:29,  6.91it/s, batch_accuracy=0.844]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  12%|█▏        | 28/225 [00:04<00:28,  6.98it/s, batch_accuracy=0.906]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  14%|█▍        | 31/225 [00:04<00:27,  7.00it/s, batch_accuracy=0.969]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  16%|█▌        | 35/225 [00:05<00:27,  6.85it/s, batch_accuracy=0.906]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  17%|█▋        | 38/225 [00:05<00:26,  6.93it/s, batch_accuracy=0.875]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  20%|█▉        | 44/225 [00:06<00:26,  6.89it/s, batch_accuracy=0.875]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  20%|██        | 45/225 [00:06<00:26,  6.87it/s, batch_accuracy=0.938]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  25%|██▌       | 57/225 [00:08<00:24,  6.84it/s, batch_accuracy=0.906]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  26%|██▌       | 58/225 [00:08<00:24,  6.80it/s, batch_accuracy=0.812]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  29%|██▉       | 65/225 [00:09<00:23,  6.83it/s, batch_accuracy=0.75] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  32%|███▏      | 72/225 [00:10<00:23,  6.59it/s, batch_accuracy=0.875]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  33%|███▎      | 74/225 [00:10<00:22,  6.65it/s, batch_accuracy=0.844]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  35%|███▍      | 78/225 [00:11<00:21,  6.73it/s, batch_accuracy=0.969]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  36%|███▋      | 82/225 [00:11<00:21,  6.70it/s, batch_accuracy=0.938]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  37%|███▋      | 84/225 [00:12<00:21,  6.69it/s, batch_accuracy=0.938]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  40%|████      | 90/225 [00:13<00:20,  6.71it/s, batch_accuracy=0.938]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  42%|████▏     | 95/225 [00:13<00:19,  6.76it/s, batch_accuracy=0.969]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  43%|████▎     | 97/225 [00:14<00:19,  6.72it/s, batch_accuracy=0.875]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  44%|████▍     | 99/225 [00:14<00:18,  6.78it/s, batch_accuracy=0.938]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  46%|████▌     | 103/225 [00:15<00:18,  6.75it/s, batch_accuracy=0.875]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  50%|████▉     | 112/225 [00:16<00:16,  6.74it/s, batch_accuracy=0.906]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  51%|█████     | 114/225 [00:16<00:16,  6.69it/s, batch_accuracy=0.688]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  52%|█████▏    | 116/225 [00:17<00:16,  6.74it/s, batch_accuracy=0.906]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  52%|█████▏    | 117/225 [00:17<00:15,  6.75it/s, batch_accuracy=0.906]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  58%|█████▊    | 130/225 [00:19<00:13,  6.89it/s, batch_accuracy=0.75] Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  59%|█████▊    | 132/225 [00:19<00:13,  6.85it/s, batch_accuracy=0.781]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  60%|██████    | 136/225 [00:19<00:12,  6.94it/s, batch_accuracy=0.844]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  61%|██████▏   | 138/225 [00:20<00:12,  6.91it/s, batch_accuracy=0.844]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  62%|██████▏   | 139/225 [00:20<00:12,  6.92it/s, batch_accuracy=0.875]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  63%|██████▎   | 141/225 [00:20<00:12,  6.93it/s, batch_accuracy=0.938]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  64%|██████▎   | 143/225 [00:20<00:11,  6.94it/s, batch_accuracy=0.938]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  65%|██████▌   | 147/225 [00:21<00:11,  6.95it/s, batch_accuracy=0.875]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  74%|███████▍  | 167/225 [00:24<00:08,  7.11it/s, batch_accuracy=0.906]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  76%|███████▌  | 171/225 [00:24<00:07,  7.14it/s, batch_accuracy=0.875]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  76%|███████▋  | 172/225 [00:25<00:07,  7.12it/s, batch_accuracy=0.875]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  79%|███████▊  | 177/225 [00:25<00:06,  7.12it/s, batch_accuracy=0.906]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  79%|███████▉  | 178/225 [00:25<00:06,  7.07it/s, batch_accuracy=0.938]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  80%|███████▉  | 179/225 [00:26<00:06,  7.07it/s, batch_accuracy=0.938]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  82%|████████▏ | 184/225 [00:26<00:05,  7.13it/s, batch_accuracy=0.875]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  82%|████████▏ | 185/225 [00:26<00:05,  7.08it/s, batch_accuracy=0.906]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  83%|████████▎ | 186/225 [00:27<00:05,  7.07it/s, batch_accuracy=0.906]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  83%|████████▎ | 187/225 [00:27<00:05,  7.11it/s, batch_accuracy=0.875]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  84%|████████▍ | 189/225 [00:27<00:05,  7.13it/s, batch_accuracy=0.812]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  84%|████████▍ | 190/225 [00:27<00:04,  7.15it/s, batch_accuracy=0.812]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  86%|████████▌ | 193/225 [00:28<00:04,  7.18it/s, batch_accuracy=0.875]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  86%|████████▌ | 194/225 [00:28<00:04,  7.14it/s, batch_accuracy=0.906]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  87%|████████▋ | 196/225 [00:28<00:04,  7.17it/s, batch_accuracy=0.812]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  88%|████████▊ | 199/225 [00:28<00:03,  7.20it/s, batch_accuracy=0.875]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  89%|████████▉ | 201/225 [00:29<00:03,  7.32it/s, batch_accuracy=0.844]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  91%|█████████ | 204/225 [00:29<00:02,  7.24it/s, batch_accuracy=0.938]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  91%|█████████ | 205/225 [00:29<00:02,  7.21it/s, batch_accuracy=0.844]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  95%|█████████▍| 213/225 [00:30<00:01,  7.36it/s, batch_accuracy=0.844]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Evaluating on Test Data:  97%|█████████▋| 218/225 [00:31<00:00,  7.28it/s, batch_accuracy=0.875]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Test Results:
#               precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93      6313
#            1       0.46      0.23      0.31       884
#
#     accuracy                           0.87      7197
#    macro avg       0.68      0.60      0.62      7197
# weighted avg       0.84      0.87      0.85      7197
